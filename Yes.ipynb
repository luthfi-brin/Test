# %%
import gempy as gp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

geo_model = gp.create_model('Model1')
geo_model = gp.init_data(geo_model, extent=[0, 791, 0, 200, -582, 0], resolution=[100, 10, 100])

gp.set_interpolator(geo_model, theano_optimizer='fast_compile', verbose=[])

p2d = gp.plot_2d(geo_model)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import gempy as gp
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# File ~\anaconda3\lib\site-packages\gempy\__init__.py:25, in <module>
#      21 SCRIPT_DIR = os.path.dirname(os.path.realpath(os.path.join(os.getcwd(), os.path.expanduser(__file__))))
#      22 sys.path.append(os.path.normpath(os.path.join(SCRIPT_DIR, PACKAGE_PARENT)))
# ---> 25 from gempy.gempy_api import *
#      26 from gempy.api_modules.getters import *
#      27 from gempy.api_modules.setters import *
#
# File ~\anaconda3\lib\site-packages\gempy\gempy_api.py:17, in <module>
#      15 from typing import Union
#      16 import warnings
# ---> 17 from gempy.core.model import Project
#      18 from gempy.core.solution import Solution
#      19 from gempy.utils.meta import _setdoc, _setdoc_pro
#
# File ~\anaconda3\lib\site-packages\gempy\core\model.py:17, in <module>
#      14 from gempy.core.data import AdditionalData, MetaData, Options, Structure, \
#      15     KrigingParameters
#      16 from gempy.core.solution import Solution
# ---> 17 from gempy.core.interpolator import InterpolatorModel, InterpolatorGravity
#      18 from gempy.utils.meta import _setdoc, _setdoc_pro
#      19 import gempy.utils.docstring as ds
#
# File ~\anaconda3\lib\site-packages\gempy\core\interpolator.py:10, in <module>
#       7 import gempy.utils.docstring as ds
#       9 import numpy as np
# ---> 10 import theano
#      13 @_setdoc_pro(
#      14     [SurfacePoints.__doc__, Orientations.__doc__, Grid.__doc__, Surfaces.__doc__, Series.__doc__,
#      15      Faults.__doc__, AdditionalData.__doc__])
#      16 class Interpolator(object):
#      17     """Class that act as:
#      18      1) linker between the data objects and the theano graph
#      19      2) container of theano graphs + shared variables
#    (...)
#      43
#      44     """
#
# File ~\anaconda3\lib\site-packages\theano\__init__.py:124, in <module>
#     120 from theano.misc.safe_asarray import _asarray
#     122 from theano.printing import pprint, pp
# --> 124 from theano.scan_module import (scan, map, reduce, foldl, foldr, clone,
#     125                                 scan_checkpoints)
#     127 from theano.updates import OrderedUpdates
#     129 # scan_module import above initializes tensor and scalar making these imports
#     130 # redundant
#     131
#    (...)
#     136
#     137 # import sparse
#
# File ~\anaconda3\lib\site-packages\theano\scan_module\__init__.py:41, in <module>
#      38 __copyright__ = "(c) 2010, Universite de Montreal"
#      39 __contact__ = "Razvan Pascanu <r.pascanu@gmail>"
# ---> 41 from theano.scan_module import scan_opt
#      42 from theano.scan_module.scan import scan
#      43 from theano.scan_module.scan_checkpoints import scan_checkpoints
#
# File ~\anaconda3\lib\site-packages\theano\scan_module\scan_opt.py:60, in <module>
#      57 import numpy as np
#      59 import theano
# ---> 60 from theano import tensor, scalar
#      61 from theano.tensor import opt, get_scalar_constant_value, Alloc, AllocEmpty
#      62 from theano import gof
#
# File ~\anaconda3\lib\site-packages\theano\tensor\__init__.py:38, in <module>
#      34 from theano.tensor.sharedvar import tensor_constructor as _shared
#      36 from theano.tensor.io import *
# ---> 38 from theano.tensor import nnet  # used for softmax, sigmoid, etc.
#      40 from theano.gradient import Rop, Lop, grad, numeric_grad, verify_grad, \
#      41     jacobian, hessian, consider_constant
#      43 from theano.tensor.sort import sort, argsort, topk, argtopk, topk_and_argtopk
#
# File ~\anaconda3\lib\site-packages\theano\tensor\nnet\__init__.py:23, in <module>
#       1 from __future__ import absolute_import, print_function, division
#       2 from .nnet import (
#       3     CrossentropyCategorical1Hot, CrossentropyCategorical1HotGrad,
#       4     CrossentropySoftmax1HotWithBiasDx, CrossentropySoftmaxArgmax1HotWithBias,
#    (...)
#      21     softmax_op, softmax_simplifier, softmax_with_bias, elu, selu,
#      22     confusion_matrix, softsign)
# ---> 23 from . import opt
#      24 from .conv import ConvOp
#      25 from .sigm import (softplus, sigmoid, sigmoid_inplace,
#      26                    scalar_sigmoid, ultra_fast_sigmoid,
#      27                    hard_sigmoid)
#
# File ~\anaconda3\lib\site-packages\theano\tensor\nnet\opt.py:11, in <module>
#       8 from theano.gof import local_optimizer
#       9 from theano.gof.opt import copy_stack_trace
# ---> 11 from theano.tensor.nnet.corr import (
#      12     CorrMM, CorrMM_gradInputs, CorrMM_gradWeights)
#      13 from theano.tensor.nnet.corr3d import (
#      14     Corr3dMM, Corr3dMM_gradInputs, Corr3dMM_gradWeights)
#      15 from theano.tensor.nnet.blocksparse import (
#      16     SparseBlockGemv,
#      17     SparseBlockOuter,
#      18     sparse_block_gemv_inplace,
#      19     sparse_block_outer_inplace)
#
# File ~\anaconda3\lib\site-packages\theano\tensor\nnet\corr.py:13, in <module>
#      11 from theano.scalar import int64, int8
#      12 from theano.tensor import as_tensor_variable, TensorType
# ---> 13 from theano.tensor.nnet.abstract_conv import get_conv_output_shape
#      14 from theano.tensor import blas_headers
#      15 from theano.tensor.blas import ldflags, blas_header_version
#
# File ~\anaconda3\lib\site-packages\theano\tensor\nnet\abstract_conv.py:9, in <module>
#       7 from six import reraise, integer_types
#       8 import sys
# ----> 9 from fractions import gcd
#      11 import theano
#      13 from theano.tensor import as_tensor_variable, patternbroadcast
#
# ImportError: cannot import name 'gcd' from 'fractions' (C:\Users\Lenovo\anaconda3\lib\fractions.py)

# %%
# Out:
# 'yudipython'
